# %%
import pandas as pd
pd.set_option('display.max_columns', None)  
pd.set_option('display.max_rows', 100)

# %% [markdown]
# # Load dataset

# %%
users_df = pd.read_csv(r"data\final\users.csv")
ad_events_df = pd.read_csv(r"data\final\ad_events.csv")
ads_df = pd.read_csv(r"data\final\ads.csv")
campaigns_df = pd.read_csv(r"data\final\campaigns.csv")

# %% [markdown]
# # Create generation column

# %%
users_df.sample(3)
# Out:
#       user_id user_gender  user_age age_group        country         location  \
# 3098     3099        Male        23     18-24         Brazil       Josephport
# 8885     8886      Female        16     16-17  United States  New Allisonfort
# 6213     6214        Male        37     35-44  United States       North Dawn
#
#                   interests  birth_year    generation
# 3098                 gaming        2002  Generation Z
# 8885  finance, sports, news        2009  Generation Z
# 6213                 gaming        1988   Millennials

# %%
# Create birth_year column from user_age column (currently year is 2025)
users_df['birth_year'] = 2025 - users_df['user_age']

# Categorize generation from birth_year column
def categorize_generation(birth_year):
    if birth_year >= 2013:
        return 'Gen Alpha'
    elif birth_year <= 2012 and birth_year >= 1995:
        return 'Generation Z'
    elif birth_year <= 1994 and birth_year >= 1980:
        return 'Millennials'
    elif birth_year <= 1979 and birth_year >= 1965:
        return 'Generation X '
    else:
        return 'The Baby Boomer Generation '

users_df['generation'] = users_df['birth_year'].apply(categorize_generation)

users_df.drop('birth_year', axis=1)
# Out:
#       user_id user_gender  user_age age_group         country  \
# 0           1      Female        24     18-24  United Kingdom
# 1           2        Male        21     18-24         Germany
# 2           3        Male        27     25-34       Australia
# 3           4      Female        28     25-34           India
# 4           5        Male        28     25-34   United States
# ...       ...         ...       ...       ...             ...
# 9995     9996        Male        18     18-24   United States
# 9996     9997        Male        24     18-24          Mexico
# 9997     9998        Male        29     25-34   United States
# 9998     9999        Male        31     25-34  United Kingdom
# 9999    10000        Male        37     35-44          Canada
#
#               location                       interests    generation
# 0       New Mariomouth                 fitness, health  Generation Z
# 1          Danielsfort        food, fitness, lifestyle  Generation Z
# 2       Vincentchester                   fashion, news  Generation Z
# 3             Lisaport           health, news, finance  Generation Z
# 4           Brownmouth  health, photography, lifestyle  Generation Z
# ...                ...                             ...           ...
# 9995        Curtisside            travel, fashion, art  Generation Z
# 9996         Brownland                         finance  Generation Z
# 9997       Watersburgh                          health  Generation Z
# 9998     South Kenneth                    art, fashion   Millennials
# 9999  New Courtneyview                         fitness   Millennials
#
# [10000 rows x 8 columns]

# %%
users_df.sample(3)
# Out:
#       user_id user_gender  user_age age_group        country       location  \
# 1871     1872        Male        22     18-24  United States  South Patrick
# 2724     2725        Male        26     25-34  United States    North Peter
# 6827     6828        Male        39     35-44  United States     Nicolebury
#
#                     interests  birth_year    generation
# 1871  lifestyle, food, health        2003  Generation Z
# 2724                   health        1999  Generation Z
# 6827                   gaming        1986   Millennials

# %%
campaigns_df.sample(3)
# Out:
#     campaign_id                name start_date  end_date  duration_days  \
# 33           34  Campaign_34_Winter   10-07-25  08-09-25             60
# 38           39      Campaign_39_Q3   18-05-25  27-07-25             70
# 47           48  Campaign_48_Winter   08-04-25  01-06-25             54
#
#     total_budget
# 33      26104.30
# 38      55638.18
# 47      13842.07

# %%
users_df['generation'].value_counts()
# Out:
# generation
# Generation Z                   6830
# Millennials                    2840
# Generation X                    301
# The Baby Boomer Generation       29
# Name: count, dtype: int64

# %% [markdown]
# # Save dataset to csv file

# %%
# users_df.to_csv(r"data\final\users.csv", index=False)

# %% [markdown]
# # Fake dataset

# %%
import random 
from datetime import datetime, timedelta

# %%
ads_df.sample(3)
# Out:
#      ad_id  campaign_id ad_platform   ad_type target_gender target_age_group  \
# 148    149           11    Facebook   Stories           All            18-24
# 122    123           33    Facebook  Carousel           All            18-24
# 79      80           46    Facebook   Stories          Male            35-44
#
#     target_interests
# 148  health, fitness
# 122  finance, sports
# 79         lifestyle

# %%
ads_df['ad_platform'].unique()
# Out:
# array(['Facebook', 'Instagram'], dtype=object)

# %%
ads_df['ad_type'].unique()
# Out:
# array(['Video', 'Stories', 'Carousel', 'Image'], dtype=object)

# %%
print(ads_df['ad_id'].min())
print(ads_df['ad_id'].max())
# Out:
# 1
# 200

# %%
ads_df['target_age_group'].unique()
# Out:
# array(['35-44', '25-34', '18-24', 'All'], dtype=object)

# %%
users_df.sample(3)
# Out:
#       user_id user_gender  user_age age_group         country       location  \
# 585       586      Female        23     18-24  United Kingdom       New Troy
# 2430     2431      Female        28     25-34       Australia  North Crystal
# 1151     1152      Female        48     45-54          Canada    Evanborough
#
#                     interests  birth_year     generation
# 585   health, gaming, finance        2002   Generation Z
# 2430                     food        1997   Generation Z
# 1151          lifestyle, news        1977  Generation X

# %%
users_df['user_gender'].unique()
# Out:
# array(['Female', 'Male', 'Other'], dtype=object)

# %%
users_df['interests'].unique()
# Out:
# array(['fitness, health', 'food, fitness, lifestyle', 'fashion, news',
#        ..., 'travel, food, technology', 'fashion, technology, food',
#        'gaming, food, health'], shape=(1641,), dtype=object)

# %%
print(users_df['user_age'].min())
print(users_df['user_age'].max())
# Out:
# 16
# 65

# %%
users_df['age_group'].unique()
# Out:
# array(['18-24', '25-34', '35-44', '45-54', '16-17', '55-65'], dtype=object)

# %%
ad_events_df.sample(3)
# Out:
#         event_id  ad_id  user_id      timestamp day_of_week time_of_day  \
# 113080    111805    106     7992  23-06-25 3:14      Monday       Night
# 391314    386650     54     3000  12-05-25 8:35      Monday     Morning
# 57397      56725     74     8153  29-05-25 9:29    Thursday     Morning
#
#         event_type      date     time  day  month  quarter  year  hour  \
# 113080       Click  23-06-25  3:14:58   23      6        2  2025     3
# 391314  Impression  12-05-25  8:35:03   12      5        2  2025     8
# 57397   Impression  29-05-25  9:29:10   29      5        2  2025     9
#
#         minute  second
# 113080      14      58
# 391314      35       3
# 57397       29      10

# %%
ad_events_df['event_type'].unique()
# Out:
# array(['Like', 'Share', 'Impression', 'Purchase', 'Click', 'Comment'],
#       dtype=object)

# %%
ad_events_df['time_of_day'].unique()
# Out:
# array(['Night', 'Morning', 'Evening', 'Afternoon'], dtype=object)

# %%
campaigns_df.sample(3)
# Out:
#     campaign_id                name start_date  end_date  duration_days  \
# 9            10  Campaign_10_Winter   17-05-25  21-07-25             65
# 0             1   Campaign_1_Launch   25-05-25  23-07-25             59
# 42           43  Campaign_43_Winter   23-04-25  12-06-25             50
#
#     total_budget
# 9       19669.27
# 0       24021.32
# 42      81350.30

# %%
# Config number of rows and ID 
num_rows = 70000
start_event_id = 400001

ad_platform_lists = ['Facebook', 'Instagram']
ad_types = ['Carousel', 'Image', 'Stories', 'Video']
genders = ['Female', 'Male', 'Other']
age_group = ['18-24', '25-34', '35-44', '45-54', '16-17', '55-65']
target_age_group = ['35-44', '25-34', '18-24', 'All']

campaign_lists = ["Campaign_1_Launch", "Campaign_2_Launch", "Campaign_3_Winter", "Campaign_4_Summer", "Campaign_5_Launch", 
                "Campaign_6_Winter", "Campaign_7_Winter", "Campaign_8_Q3", "Campaign_9_Launch", "Campaign_10_Winter", 
                "Campaign_11_Q3", "Campaign_12_Q3", "Campaign_13_Winter", "Campaign_14_Summer", "Campaign_15_Launch", 
                "Campaign_16_Winter", "Campaign_17_Launch", "Campaign_18_Q3", "Campaign_19_Winter", "Campaign_20_Winter", 
                "Campaign_21_Winter", "Campaign_22_Q3", "Campaign_23_Winter", "Campaign_24_Summer", "Campaign_25_Winter", 
                "Campaign_26_Winter", "Campaign_27_Q3", "Campaign_28_Winter", "Campaign_29_Winter", "Campaign_30_Winter", 
                "Campaign_31_Summer", "Campaign_32_Summer", "Campaign_33_Summer", "Campaign_34_Winter", "Campaign_35_Launch", 
                "Campaign_36_Q3", "Campaign_37_Launch", "Campaign_38_Q3", "Campaign_39_Q3", "Campaign_40_Summer", 
                "Campaign_41_Winter", "Campaign_42_Summer", "Campaign_43_Winter", "Campaign_44_Q3", "Campaign_45_Summer", 
                "Campaign_46_Winter", "Campaign_47_Launch", "Campaign_48_Winter", "Campaign_49_Winter", "Campaign_50_Summer"]


countries = {
    'United States': ['New York', 'Los Angeles', 'Chicago'],
    'United Kingdom': ['London', 'Manchester', 'Liverpool'],
    'Vietnam': ['Ho Chi Minh City', 'Hanoi', 'Da Nang'],
    'Germany': ['Berlin', 'Munich', 'Hamburg']
}
interests = ['gaming', 'fashion', 'travel', 'technology', 'fitness', 'cooking', 'music']
event_types = ['Like', 'Share', 'Impression', 'Purchase', 'Click', 'Comment']

data = []

def get_time_of_day(h):
    if 6 <= h < 12:
        return 'Morning'
    elif 12 <= h < 18:
        return 'Afternoon'
    elif 18 <= h < 22:
        return 'Evening'
    else:
        return 'Night'

def get_user_age_group(age):
    if 16 <= age <= 17:
        return '16-17'
    elif 18 <= age <= 24:
        return '18-24'
    elif 25 <= age <= 34:
        return '25-34'
    elif 35 <= age <= 44:
        return '35-44'
    elif 45 <= age <= 54:
        return '45-54'
    elif 55 <= age <= 65:
        return '55-65'
    

for i in range(num_rows):
    ad_platform_id = random.randint(0,1)
    ad_platform = ad_platform_lists[ad_platform_id]
    ad_type = random.choice(ad_types)
    
    if ad_type == 'Video':
        if ad_platform == 'Facebook':
            # Facebook Video - high Click rate
            weights = [5, 5, 40, 5, 40, 5]  # Higher Click weight
        else:
            # Instagram Video - moderate Click rate
            weights = [5, 5, 50, 5, 30, 5]
    elif ad_type == 'Stories':
        if ad_platform == 'Instagram':
            # Instagram Stories - high Click rate
            weights = [5, 5, 45, 5, 38, 7]  # Higher Click weight
        else:
            # Facebook Stories - lower Click rate
            weights = [5, 5, 75, 2, 8, 5]
    else:
        # Other ad types - lower Click rate
        weights = [5, 5, 80, 2, 5, 3]
        
    event_types_selected = random.choices(event_types, weights=weights, k=1)[0]
    
    start_date = datetime(2025, 7, 5)
    end_date = datetime(2025, 7, 31)
    days_range = (end_date - start_date).days
    date = start_date + timedelta(days=random.randint(0, days_range))
    
    
    ad_platform_id = random.randint(0,1)
    
    # Select campaign and get the selected campaign id 
    campaign = random.choice(campaign_lists)
    campaign_id = campaign_lists.index(campaign) + 1
    target_interests = ', '.join(random.choices(interests, k=random.randint(1, 3)))
    
    # Time
    second = random.randint(0, 59)
    minute = random.randint(0, 59)
    hour = random.randint(0, 23)
    time_of_day = get_time_of_day(hour)
    
    # User
    user_gender = random.choice(genders)
    user_age = random.randint(16, 65)
    age_group = get_user_age_group(user_age)
    user_interests = random.choice(interests)
    
    # Country & Location
    country = random.choice(list(countries.keys()))
    country_id = list(countries.keys()).index(country) + 1
    location = random.choice(countries[country])
    location_id = random.randint(1, 7706)
    
    row = {
        'event_id': start_event_id + i,
        'date': date.strftime('%Y-%m-%d'),
        'time': f"{hour}:{minute}:{second}",
        
        'ad_id': random.randint(1, 200),
        'target_gender': random.choice(genders),
        'target_age_group': random.choice(target_age_group),
        'target_interests': target_interests,
        
        'ad_platform_id': ad_platform_id + 1,
        'ad_type_id': ad_types.index(ad_type) + 1,
        'campaign_id': campaign_id, 
        'ad_platform': ad_platform_lists[ad_platform_id],
        'ad_type': ad_type,
        'name': campaign,  
        'duration_days': random.randint(7, 60),
        'total_budget': round(random.uniform(5000, 50000), 2),
        
        'day': date.day,
        'month': date.month,
        'quarter': (date.month - 1) // 3 + 1,
        'year': date.year,
        'day_of_week': date.strftime('%A'),
        
        'second': second,
        'minute': minute,
        'hour': hour,
        'time_of_day': time_of_day,
        
        
        'user_gender': user_gender,
        'user_age': user_age,
        'age_group': age_group,
        
        'location_id': location_id,
        'country_id': country_id,
        'interests': user_interests,
        'event_type_name': event_types_selected,
        'location_name': location,
        'country_name': country
    }
    data.append(row)

# %%
fake_data = pd.DataFrame(data)

# %%
fake_data.shape
# Out:
# (70000, 33)

# %%
fake_data.sample(4)
# Out:
#        event_id        date      time  ad_id target_gender target_age_group  \
# 60547    460548  2025-07-19   1:14:38     62        Female            35-44
# 36123    436124  2025-07-15   8:13:42    175          Male            18-24
# 14972    414973  2025-07-08   8:10:49    198        Female            25-34
# 69850    469851  2025-07-26  13:38:57    200         Other            18-24
#
#         target_interests  ad_platform_id  ad_type_id  campaign_id ad_platform  \
# 60547              music               2           2           24   Instagram
# 36123  music, technology               1           4           14    Facebook
# 14972            fashion               1           2           28    Facebook
# 69850     gaming, travel               1           3           23    Facebook
#
#        ad_type                name  duration_days  total_budget  day  month  \
# 60547    Image  Campaign_24_Summer             26      20968.38   19      7
# 36123    Video  Campaign_14_Summer             10      14734.81   15      7
# 14972    Image  Campaign_28_Winter             13      19496.69    8      7
# 69850  Stories  Campaign_23_Winter             15      12909.39   26      7
#
#        quarter  year day_of_week  second  minute  hour time_of_day  \
# 60547        3  2025    Saturday      38      14     1       Night
# 36123        3  2025     Tuesday      42      13     8     Morning
# 14972        3  2025     Tuesday      49      10     8     Morning
# 69850        3  2025    Saturday      57      38    13   Afternoon
#
#       user_gender  user_age age_group  location_id  country_id interests  \
# 60547      Female        32     25-34          403           1   fitness
# 36123      Female        55     55-65         6171           3     music
# 14972      Female        41     35-44         3387           2   cooking
# 69850        Male        56     55-65          418           1   fitness
#
#       event_type_name location_name    country_name
# 60547      Impression       Chicago   United States
# 36123      Impression       Da Nang         Vietnam
# 14972      Impression    Manchester  United Kingdom
# 69850      Impression   Los Angeles   United States

# %%
fake_data['event_type_name'].value_counts()
# Out:
# event_type_name
# Impression    46118
# Click         11758
# Share          3507
# Like           3476
# Comment        2950
# Purchase       2191
# Name: count, dtype: int64

# %% [markdown]
# ## Save fake data

# %%
# fake_data.to_csv(r'data\fake_data\fake_data.csv', index=False)

# %% [markdown]
# # Combine locker_data with fake_data

# %%
locker_data_df = pd.read_csv(r'data\final\looker_data.csv')
locker_data_df.sample(3)
# Out:
#         event_id        date      time  ad_id target_gender target_age_group  \
# 57788      73251  2025-06-07  13:26:54     71          Male              All
# 138969     40614  2025-06-14  23:22:47    162           All            35-44
# 303314    235067  2025-05-10   9:29:49     99        Female            35-44
#
#             target_interests  ad_platform_id  ad_type_id  campaign_id  \
# 57788           art, fashion               1           3           21
# 138969                gaming               2           1            6
# 303314  photography, fitness               1           2            8
#
#        ad_platform   ad_type                name  duration_days  total_budget  \
# 57788     Facebook   Stories  Campaign_21_Winter             64      37290.81
# 138969   Instagram  Carousel   Campaign_6_Winter             84      78607.49
# 303314    Facebook     Image       Campaign_8_Q3             41      39953.19
#
#         day  month  quarter  year day_of_week  second  minute  hour  \
# 57788     7      6        2  2025    Saturday      54      26    13
# 138969   14      6        2  2025    Saturday      47      22    23
# 303314   10      5        2  2025    Saturday      49      29     9
#
#        time_of_day user_gender  user_age age_group  location_id  country_id  \
# 57788    Afternoon       Other        30     25-34         5217           6
# 138969     Evening        Male        42     35-44         5846           6
# 303314     Morning        Male        36     35-44         6856           7
#
#                          interests event_type_name  location_name country_name
# 57788                 food, travel      Impression  Port Daletown        India
# 138969        fashion, photography      Impression    Ryanborough        India
# 303314  travel, finance, lifestyle      Impression    Trevormouth        Japan

# %%
fake_data.sample(3)
# Out:
#       event_id        date      time  ad_id target_gender target_age_group  \
# 9691    409692  2025-07-15  22:34:11    115         Other            35-44
# 8046    408047  2025-07-22   4:36:20     46         Other              All
# 6040    406041  2025-07-20   0:28:40      4        Female            25-34
#
#             target_interests  ad_platform_id  ad_type_id  campaign_id  \
# 9691              technology               2           3           40
# 8046          gaming, travel               2           1            3
# 6040  gaming, music, cooking               1           4           49
#
#      ad_platform   ad_type                name  duration_days  total_budget  \
# 9691   Instagram   Stories  Campaign_40_Summer             15      19965.14
# 8046   Instagram  Carousel   Campaign_3_Winter             58      41924.35
# 6040    Facebook     Video  Campaign_49_Winter             37      37316.31
#
#       day  month  quarter  year day_of_week  second  minute  hour time_of_day  \
# 9691   15      7        3  2025     Tuesday      11      34    22       Night
# 8046   22      7        3  2025     Tuesday      20      36     4       Night
# 6040   20      7        3  2025      Sunday      40      28     0       Night
#
#      user_gender  user_age age_group  location_id  country_id   interests  \
# 9691       Other        51     45-54         4501           4  technology
# 8046      Female        46     45-54         5661           2  technology
# 6040       Other        45     45-54         3329           2  technology
#
#      event_type_name location_name    country_name
# 9691      Impression        Munich         Germany
# 8046      Impression    Manchester  United Kingdom
# 6040           Click     Liverpool  United Kingdom

# %%
processed_df = pd.concat([locker_data_df, fake_data], ignore_index=True).drop_duplicates()
print(f"Combined (no duplicates): {len(processed_df)} rows")
# Out:
# Combined (no duplicates): 470000 rows

# %%
processed_df.sample(5)
# Out:
#         event_id        date      time  ad_id target_gender target_age_group  \
# 166786     42836  2025-07-18  10:22:31     67           All            18-24
# 300827    233567  2025-06-13  14:49:13     85        Female            18-24
# 23033     104071  2025-06-23  13:01:55     23           All            18-24
# 55585     121364  2025-07-04  20:26:01     33        Female              All
# 44909      22316  2025-08-06   0:26:49    170          Male            35-44
#
#           target_interests  ad_platform_id  ad_type_id  campaign_id  \
# 166786  technology, travel               1           1           40
# 300827     finance, sports               1           1           20
# 23033                 news               1           2           33
# 55585          photography               2           1           15
# 44909               sports               2           2           40
#
#        ad_platform   ad_type                name  duration_days  total_budget  \
# 166786    Facebook  Carousel  Campaign_40_Summer             47      53936.41
# 300827    Facebook  Carousel  Campaign_20_Winter             90      98904.66
# 23033     Facebook     Image  Campaign_33_Summer             87      59264.68
# 55585    Instagram  Carousel  Campaign_15_Launch             82      85407.23
# 44909    Instagram     Image  Campaign_40_Summer             47      53936.41
#
#         day  month  quarter  year day_of_week  second  minute  hour  \
# 166786   18      7        3  2025      Friday      31      22    10
# 300827   13      6        2  2025      Friday      13      49    14
# 23033    23      6        2  2025      Monday      55       1    13
# 55585     4      7        3  2025      Friday       1      26    20
# 44909     6      8        3  2025   Wednesday      49      26     0
#
#        time_of_day user_gender  user_age age_group  location_id  country_id  \
# 166786     Morning        Male        29     25-34         5525          10
# 300827   Afternoon        Male        22     18-24         2238           6
# 23033    Afternoon        Male        33     25-34         6332          10
# 55585      Evening        Male        27     25-34         3354           9
# 44909        Night      Female        16     16-17         3887           2
#
#                       interests event_type_name      location_name  \
# 166786   lifestyle, health, art            Like      Port Ryanland
# 300827               technology           Click          Jamesberg
# 23033        fashion, lifestyle      Impression  South Johnborough
# 55585   lifestyle, news, gaming      Impression          Lewisview
# 44909                technology      Impression            New Ann
#
#           country_name
# 166786   United States
# 300827           India
# 23033    United States
# 55585   United Kingdom
# 44909           Brazil

# %%
print(processed_df['date'].min())
print(processed_df['date'].max())
# Out:
# 2025-05-07
# 2025-08-06

# %% [markdown]
# ##

# %% [markdown]
# ## Save combined dataset

# %%
processed_df.to_csv(r'data\fake_data\processed_data.csv', index=False)
